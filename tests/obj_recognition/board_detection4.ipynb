# %%
import cv2 as cv
import numpy as np
import math
from matplotlib import pyplot as plt

# %%
from chesster.obj_recognition.chessboard_recognition import ChessBoardRecognition

img = cv.imread('img/2021-12-05-022201.jpg')

board = ChessBoardRecognition.from_image(img, True)

# %%
img2 = cv.imread('img/2021-12-05-171059.jpg')
board2 = ChessBoardRecognition.from_image(img2, True)

# %%
for v in ['img/2021-12-05-171142.jpg']:
    print(f'Image: {v}')
    img = cv.imread(v)
    ChessBoardRecognition.from_image(img, True)
# Out:
# Image: img/2021-12-05-171142.jpg
