# %%
from chesster.obj_recognition.nn.datasets import ChesspieceDataset
from chesster.obj_recognition.nn.utils import *
import cv2 as cv
import numpy as np
import torch

# %%
dataset = ChesspieceDataset('dataset/v1/train/images', 'dataset/v1/train/labels', 300, 300, CLASSES, None)

NUM_SAMPLE_TO_VISUALIZE = 20

for i in range(NUM_SAMPLE_TO_VISUALIZE):
    image, target = dataset[i]
    image = image.permute(1, 2, 0).detach().to(DEVICE).numpy()
    visualize_sample(image, target, True)
