# %%
from chesster.obj_recognition.nn.detect import Detect
from pathlib import Path
import cv2 as cv
import logging

# %%
logging.basicConfig(level=logging.INFO)
detector = Detect('rcnn', Path('dataset/model_50.pth'), 0.5)

# %%
image = cv.imread('dataset/v1/test/images/0b47311f426ff926578c9d738d683e76_jpg.rf.40183eae584a653181bbd795ba3c353f.jpg')
detector.classify(image, True)
# Out:
# INFO:chesster.obj_recognition.nn.detect:Classification complete. Score: [(0.529336, 'P'), (0.41755345, 'B'), (0.27764878, 'N'), (0.1914648, 'R'), (0.17682423, 'N'), (0.15375097, 'R'), (0.12739274, 'Q'), (0.12004786, 'N'), (0.071188286, 'R'), (0.063552275, 'r'), (0.056466736, 'K'), (0.055562235, 'b')]

# %%
image = cv.imread('dataset/v1/test/images/2f6fb003bb89cd401322a535acb42f65_jpg.rf.66c0a46773a9cd583fb96c3df41a9e0c.jpg')
detector.classify(image, True)
# Out:
# INFO:chesster.obj_recognition.nn.detect:Classification complete. Score: [(0.9948079, 'P'), (0.9914863, 'p'), (0.9892047, 'p'), (0.98376924, 'p'), (0.97861266, 'P'), (0.97798187, 'p'), (0.97221273, 'B'), (0.95617694, 'P'), (0.95092803, 'P'), (0.94712335, 'P'), (0.9366377, 'P'), (0.92126024, 'K'), (0.913728, 'p'), (0.88825846, 'p'), (0.8834208, 'p'), (0.8792622, 'p'), (0.86838275, 'Q'), (0.8377984, 'p'), (0.83300227, 'N'), (0.8316491, 'k'), (0.8298452, 'p'), (0.7774358, 'R'), (0.7702081, 'N'), (0.7579494, 'p'), (0.7556332, 'R'), (0.72969913, 'P'), (0.70219994, 'N'), (0.6807304, 'b'), (0.6593432, 'n'), (0.6332806, 'p'), (0.6284873, 'r'), (0.62528545, 'p'), (0.59603375, 'P'), (0.5857161, 'q'), (0.579959, 'Q'), (0.572857, 'b'), (0.5445969, 'b'), (0.5445209, 'p'), (0.54052657, 'k'), (0.5300636, 'p'), (0.5251531, 'P'), (0.49875364, 'P'), (0.46821076, 'P'), (0.46798497, 'r'), (0.46138898, 'B'), (0.42331773, 'N'), (0.40629116, 'p'), (0.39188176, 'b'), (0.39041865, 'b'), (0.36764807, 'N'), (0.
# ...

# %%
image = cv.imread('dataset/v1/test/images/7a34d8620235048917b28bcfd3b5572b_jpg.rf.450c577e3be66b5232c54ffc9ec9e6b7.jpg')
detector.classify(image, True)
# Out:
# INFO:chesster.obj_recognition.nn.detect:Classification complete. Score: [(0.7487177, 'b'), (0.32879272, 'N'), (0.27464476, 'r'), (0.18752725, 'N'), (0.16378589, 'p'), (0.14219451, 'R'), (0.09587957, 'R'), (0.08622792, 'k'), (0.06703531, 'P'), (0.0594509, 'q')]
